# %%
from datetime import datetime
datetime.strptime(datetime.now().strftime("%Y-%m-%dT%H:%M:%SZ"), "%Y-%m-%dT%H:%M:%SZ")
# datetime.strptime(article_data.get("pubDate", datetime.now().strftime("%Y-%m-%dT%H:%M:%SZ")), "%Y-%m-%dT%H:%M:%SZ")
# Out:
# datetime.datetime(2025, 3, 21, 19, 47, 31)

# %% [markdown]
# # Yahoo Finance News Collector Demo
#
# This notebook demonstrates how to use the Yahoo Finance News collector module to retrieve company news articles.

# %%
import sys
import pandas as pd
from datetime import datetime
from pathlib import Path

# Add the project root to the Python path
project_root = Path.cwd().parent.parent
if str(project_root) not in sys.path:
    sys.path.append(str(project_root))
project_root

# %%
# Import the yahoo_news module
from tumkwe_invest.datacollection.collectors.yahoo_news import get_yahoo_finance_news

# %% [markdown]
# ## Get Yahoo Finance News for a Company
#
# Let's fetch news for a few example companies.

# %%
# Define ticker symbols for some popular companies
tickers = ['AAPL', 'MSFT', 'GOOGL']

# Number of articles to retrieve per company
max_articles = 5

# %%
# Get news for Apple
apple_news = get_yahoo_finance_news('AAPL', max_articles=max_articles)

print(f"Retrieved {len(apple_news)} news articles for AAPL")

# Display the articles in a DataFrame for better visualization
if apple_news:
    news_df = pd.DataFrame([
        {
            "title": article.title,
            "publication": article.publication,
            "date": article.date,
            "summary": article.summary[:100] + "..." if len(article.summary) > 100 else article.summary,
            "url": article.url
        } for article in apple_news
    ])
    display(news_df)
# Out:
# [{"id": "aa382e73-42e4-3552-ab3e-b38e8088ad2b", "content": {"id": "aa382e73-42e4-3552-ab3e-b38e8088ad2b", "contentType": "STORY", "title": "ChatGPT: Everything you need to know about the AI-powered chatbot", "description": "", "summary": "ChatGPT, OpenAI\u2019s text-generating AI chatbot, has taken the world by storm since its launch in November 2022. What started as a tool to supercharge productivity through writing essays and code with short text prompts has evolved into a behemoth with 300 million weekly active users. 2024 was a big year for OpenAI, from its partnership with Apple for its generative AI offering, Apple Intelligence, the release of GPT-4o with voice capabilities, and the highly-anticipated launch of its text-to-video", "pubDate": "2025-03-21T15:46:45Z", "displayTime": "2025-03-21T15:46:45Z", "isHosted": true, "bypassModal": false, "previewUrl": null, "thumbnail": null, "provider": {"displayName": "TechCrunch", "url": "https://techcrunch.com/"}, "canonicalUrl": {"url": "https://techcrunch.com/2025/03/21/chatgpt-everything-to-know-about-the-ai-chatbot/", "site": "finance", "region": "US", "lang": "en-US"}, "clickThroughUrl": {"url": "https://finance.yahoo.com/news/chatgpt-everything-know-ai-powered-210339686.html", "site": "finance", "region": "US", "lang": "en-US"}, "metadata": {"editorsPick": true}, "finance": {"premiumFinance": {"isPremiumNews": false, "isPremiumFreeNews": false}}, "storyline": {"storylineItems": [{"content": {"id": "ae5306fc-8f87-4146-8883-7f2f42a80894", "contentType": "STORY", "isHosted": true, "title": "Short sellers have made $15 billion betting against Tesla and Nvidia in 2025", "thumbnail": {"originalUrl": "https://s.yimg.com/os/creatr-uploaded-images/2025-03/d56e9090-059e-11f0-bd69-fb14180a4ab0", "originalWidth": 5221, "originalHeight": 3485, "caption": "", "resolutions": null}, "provider": {"displayName": "Yahoo Finance", "sourceId": "yahoofinance.com"}, "previewUrl": null, "providerContentUrl": "", "canonicalUrl": {"url": "https://finance.yahoo.com/news/short-sellers-have-made-15-billion-betting-against-tesla-and-nvidia-in-2025-164652312.html"}, "clickThroughUrl": {"url": "https://finance.yahoo.com/news/short-sellers-have-made-15-billion-betting-against-tesla-and-nvidia-in-2025-164652312.html"}}}, {"content": {"id": "37271c90-f6ed-3928-a918-97497564c78b", "contentType": "STORY", "isHosted": true, "title": "Apple faces lawsuit over Apple Intelligence delays", "thumbnail": null, "provider": {"displayName": "TechCrunch", "sourceId": "techcrunch_for_finance_733"}, "previewUrl": null, "providerContentUrl": "https://techcrunch.com/2025/03/20/apple-faces-lawsuit-over-apple-intelligence-delays/", "canonicalUrl": {"url": "https://techcrunch.com/2025/03/20/apple-faces-lawsuit-over-apple-intelligence-delays/"}, "clickThroughUrl": {"url": "https://finance.yahoo.com/news/apple-faces-lawsuit-over-apple-221952721.html"}}}]}}}, {"id": "aa34a3b0-6507-3afc-90e7-5846e662092b", "content": {"id": "aa34a3b0-6507-3afc-90e7-5846e662092b", "contentType": "VIDEO", "title": "Short sellers have already profited over $24B from Mag 7 losses", "description": "<p>Short sellers, or traders who profit from a stock's decline, have already made over $24 billion in profit this year from \"Magnificent Seven\" market losses, <a data-i13n=\"cpos:1;pos:1\" href=\"https://finance.yahoo.com/news/short-sellers-have-made-15-billion-betting-against-tesla-and-nvidia-in-2025-164652312.html?fr=sycsrp_catchall\">including $15 billion in profit</a> from declines in Nvidia (<a data-i13n=\"cpos:2;pos:1\" href=\"https://finance.yahoo.com/quote/NVDA\">NVDA</a>) and Tesla (<a data-i13n=\"cpos:3;pos:1\" href=\"https://finance.yahoo.com/quote/TSLA\">TSLA</a>) alone.</p>\n<p>Yahoo Finance Senior Markets Reporter <a data-i13n=\"cpos:4;pos:1\" href=\"https://finance.yahoo.com/author/josh-schafer/\">Josh Schafer</a> examines the details in today's Chart of the Day.</p>\n<p>To watch more expert insights and analysis on the latest market action, ...
# Successfully retrieved 5 news articles for AAPL from Yahoo Finance
# Retrieved 5 news articles for AAPL
#                                                title          publication  \
# 0  ChatGPT: Everything you need to know about the...           TechCrunch
# 1  Short sellers have already profited over $24B ...  Yahoo Finance Video
# 2  Apple, in effort to turn around Siri, shakes u...             TipRanks
# 3  Accenture reports Q2 beat, Apple TV+ losing $1...             TipRanks
# 4  Report: Apple Reassigns Siri Development to Vi...        GuruFocus.com
#
#                  date                                            summary  \
# 0 2025-03-21 15:46:45  ChatGPT, OpenAI’s text-generating AI chatbot, ...
# 1 2025-03-20 21:42:33  Short sellers, or traders who profit from a st...
# 2 2025-03-21 16:17:22  Apple (AAPL) CEO Tim Cook lost faith in AI hea...
# 3 2025-03-21 16:16:26  The major indexes were fractionally higher nea...
# 4 2025-03-21 15:51:44  Siri is no longer under AI chief John Giannand...
#
#                                                  url
# 0  https://finance.yahoo.com/news/chatgpt-everyth...
# 1  https://finance.yahoo.com/video/short-sellers-...
# 2  https://finance.yahoo.com/news/apple-effort-tu...
# 3  https://finance.yahoo.com/news/accenture-repor...
# 4  https://finance.yahoo.com/news/report-apple-re...

# %% [markdown]
# ## Collect News for Multiple Companies

# %%
# Collect news for all companies in our ticker list
all_news = {}

for ticker in tickers:
    news = get_yahoo_finance_news(ticker, max_articles=max_articles)
    all_news[ticker] = news
    print(f"Retrieved {len(news)} news articles for {ticker}")
# Out:
# [{"id": "aa382e73-42e4-3552-ab3e-b38e8088ad2b", "content": {"id": "aa382e73-42e4-3552-ab3e-b38e8088ad2b", "contentType": "STORY", "title": "ChatGPT: Everything you need to know about the AI-powered chatbot", "description": "", "summary": "ChatGPT, OpenAI\u2019s text-generating AI chatbot, has taken the world by storm since its launch in November 2022. What started as a tool to supercharge productivity through writing essays and code with short text prompts has evolved into a behemoth with 300 million weekly active users. 2024 was a big year for OpenAI, from its partnership with Apple for its generative AI offering, Apple Intelligence, the release of GPT-4o with voice capabilities, and the highly-anticipated launch of its text-to-video", "pubDate": "2025-03-21T15:46:45Z", "displayTime": "2025-03-21T15:46:45Z", "isHosted": true, "bypassModal": false, "previewUrl": null, "thumbnail": null, "provider": {"displayName": "TechCrunch", "url": "https://techcrunch.com/"}, "canonicalUrl": {"url": "https://techcrunch.com/2025/03/21/chatgpt-everything-to-know-about-the-ai-chatbot/", "site": "finance", "region": "US", "lang": "en-US"}, "clickThroughUrl": {"url": "https://finance.yahoo.com/news/chatgpt-everything-know-ai-powered-210339686.html", "site": "finance", "region": "US", "lang": "en-US"}, "metadata": {"editorsPick": true}, "finance": {"premiumFinance": {"isPremiumNews": false, "isPremiumFreeNews": false}}, "storyline": {"storylineItems": [{"content": {"id": "ae5306fc-8f87-4146-8883-7f2f42a80894", "contentType": "STORY", "isHosted": true, "title": "Short sellers have made $15 billion betting against Tesla and Nvidia in 2025", "thumbnail": {"originalUrl": "https://s.yimg.com/os/creatr-uploaded-images/2025-03/d56e9090-059e-11f0-bd69-fb14180a4ab0", "originalWidth": 5221, "originalHeight": 3485, "caption": "", "resolutions": null}, "provider": {"displayName": "Yahoo Finance", "sourceId": "yahoofinance.com"}, "previewUrl": null, "providerContentUrl": "", "canonicalUrl": {"url": "https://finance.yahoo.com/news/short-sellers-have-made-15-billion-betting-against-tesla-and-nvidia-in-2025-164652312.html"}, "clickThroughUrl": {"url": "https://finance.yahoo.com/news/short-sellers-have-made-15-billion-betting-against-tesla-and-nvidia-in-2025-164652312.html"}}}, {"content": {"id": "37271c90-f6ed-3928-a918-97497564c78b", "contentType": "STORY", "isHosted": true, "title": "Apple faces lawsuit over Apple Intelligence delays", "thumbnail": null, "provider": {"displayName": "TechCrunch", "sourceId": "techcrunch_for_finance_733"}, "previewUrl": null, "providerContentUrl": "https://techcrunch.com/2025/03/20/apple-faces-lawsuit-over-apple-intelligence-delays/", "canonicalUrl": {"url": "https://techcrunch.com/2025/03/20/apple-faces-lawsuit-over-apple-intelligence-delays/"}, "clickThroughUrl": {"url": "https://finance.yahoo.com/news/apple-faces-lawsuit-over-apple-221952721.html"}}}]}}}, {"id": "aa34a3b0-6507-3afc-90e7-5846e662092b", "content": {"id": "aa34a3b0-6507-3afc-90e7-5846e662092b", "contentType": "VIDEO", "title": "Short sellers have already profited over $24B from Mag 7 losses", "description": "<p>Short sellers, or traders who profit from a stock's decline, have already made over $24 billion in profit this year from \"Magnificent Seven\" market losses, <a data-i13n=\"cpos:1;pos:1\" href=\"https://finance.yahoo.com/news/short-sellers-have-made-15-billion-betting-against-tesla-and-nvidia-in-2025-164652312.html?fr=sycsrp_catchall\">including $15 billion in profit</a> from declines in Nvidia (<a data-i13n=\"cpos:2;pos:1\" href=\"https://finance.yahoo.com/quote/NVDA\">NVDA</a>) and Tesla (<a data-i13n=\"cpos:3;pos:1\" href=\"https://finance.yahoo.com/quote/TSLA\">TSLA</a>) alone.</p>\n<p>Yahoo Finance Senior Markets Reporter <a data-i13n=\"cpos:4;pos:1\" href=\"https://finance.yahoo.com/author/josh-schafer/\">Josh Schafer</a> examines the details in today's Chart of the Day.</p>\n<p>To watch more expert insights and analysis on the latest market action, ...
# Successfully retrieved 5 news articles for AAPL from Yahoo Finance
# Retrieved 5 news articles for AAPL
# [{"id": "aa382e73-42e4-3552-ab3e-b38e8088ad2b", "content": {"id": "aa382e73-42e4-3552-ab3e-b38e8088ad2b", "contentType": "STORY", "title": "ChatGPT: Everything you need to know about the AI-powered chatbot", "description": "", "summary": "ChatGPT, OpenAI\u2019s text-generating AI chatbot, has taken the world by storm since its launch in November 2022. What started as a tool to supercharge productivity through writing essays and code with short text prompts has evolved into a behemoth with 300 million weekly active users. 2024 was a big year for OpenAI, from its partnership with Apple for its generative AI offering, Apple Intelligence, the release of GPT-4o with voice capabilities, and the highly-anticipated launch of its text-to-video", "pubDate": "2025-03-21T15:46:45Z", "displayTime": "2025-03-21T15:46:45Z", "isHosted": true, "bypassModal": false, "previewUrl": null, "thumbnail": null, "provider": {"displayName": "TechCrunch", "url": "https://techcrunch.com/"}, "canonicalUrl": {"url": "https://techcrunch.com/2025/03/21/chatgpt-everything-to-know-about-the-ai-chatbot/", "site": "finance", "region": "US", "lang": "en-US"}, "clickThroughUrl": {"url": "https://finance.yahoo.com/news/chatgpt-everything-know-ai-powered-210339686.html", "site": "finance", "region": "US", "lang": "en-US"}, "metadata": {"editorsPick": true}, "finance": {"premiumFinance": {"isPremiumNews": false, "isPremiumFreeNews": false}}, "storyline": {"storylineItems": [{"content": {"id": "3db3dc34-4451-3d4d-9352-b9a1adeb6de9", "contentType": "STORY", "isHosted": true, "title": "Microsoft is exploring a way to credit contributors to AI training data", "thumbnail": null, "provider": {"displayName": "TechCrunch", "sourceId": "techcrunch_for_finance_733"}, "previewUrl": null, "providerContentUrl": "https://techcrunch.com/2025/03/21/microsoft-is-exploring-a-way-to-credit-contributors-to-ai-training-data/", "canonicalUrl": {"url": "https://techcrunch.com/2025/03/21/microsoft-is-exploring-a-way-to-credit-contributors-to-ai-training-data/"}, "clickThroughUrl": {"url": "https://finance.yahoo.com/news/microsoft-exploring-way-credit-contributors-151521500.html"}}}, {"content": {"id": "ae5306fc-8f87-4146-8883-7f2f42a80894", "contentType": "STORY", "isHosted": true, "title": "Short sellers have made $15 billion betting against Tesla and Nvidia in 2025", "thumbnail": {"originalUrl": "https://s.yimg.com/os/creatr-uploaded-images/2025-03/d56e9090-059e-11f0-bd69-fb14180a4ab0", "originalWidth": 5221, "originalHeight": 3485, "caption": "", "resolutions": null}, "provider": {"displayName": "Yahoo Finance", "sourceId": "yahoofinance.com"}, "previewUrl": null, "providerContentUrl": "", "canonicalUrl": {"url": "https://finance.yahoo.com/news/short-sellers-have-made-15-billion-betting-against-tesla-and-nvidia-in-2025-164652312.html"}, "clickThroughUrl": {"url": "https://finance.yahoo.com/news/short-sellers-have-made-15-billion-betting-against-tesla-and-nvidia-in-2025-164652312.html"}}}]}}}, {"id": "aa34a3b0-6507-3afc-90e7-5846e662092b", "content": {"id": "aa34a3b0-6507-3afc-90e7-5846e662092b", "contentType": "VIDEO", "title": "Short sellers have already profited over $24B from Mag 7 losses", "description": "<p>Short sellers, or traders who profit from a stock's decline, have already made over $24 billion in profit this year from \"Magnificent Seven\" market losses, <a data-i13n=\"cpos:1;pos:1\" href=\"https://finance.yahoo.com/news/short-sellers-have-made-15-billion-betting-against-tesla-and-nvidia-in-2025-164652312.html?fr=sycsrp_catchall\">including $15 billion in profit</a> from declines in Nvidia (<a data-i13n=\"cpos:2;pos:1\" href=\"https://finance.yahoo.com/quote/NVDA\">NVDA</a>) and Tesla (<a data-i13n=\"cpos:3;pos:1\" href=\"https://finance.yahoo.com/quote/TSLA\">TSLA</a>) alone.</p>\n<p>Yahoo Finance Senior Markets Reporter <a data-i13n=\"cpos:4;pos:1\" href=\"https://finance.yahoo.com/author/josh-schafer/\">Josh Schafer</a> examines the details in today's Chart of the Day.</p> ...
# Error processing Yahoo Finance article: 'NoneType' object has no attribute 'get'
# Successfully retrieved 4 news articles for MSFT from Yahoo Finance
# Retrieved 4 news articles for MSFT
# [{"id": "6b98db6d-3501-4f8c-b00e-653c65fa8e78", "content": {"id": "6b98db6d-3501-4f8c-b00e-653c65fa8e78", "contentType": "STORY", "title": "3 of Goldman Sachs' best investing tips for currently volatile markets", "description": "", "summary": "Volatile times in markets require precision, Goldman Sachs reminds investors.", "pubDate": "2025-03-21T13:30:52Z", "displayTime": "2025-03-21T13:30:52Z", "isHosted": true, "bypassModal": false, "previewUrl": null, "thumbnail": {"originalUrl": "https://s.yimg.com/os/creatr-uploaded-images/2025-03/fa9a73c0-064d-11f0-bfef-335ca4dffab0", "originalWidth": 4032, "originalHeight": 2688, "caption": "", "resolutions": [{"url": "https://s.yimg.com/uu/api/res/1.2/zHWTbT2JGzEeUpcJTJaQDw--~B/aD0yNjg4O3c9NDAzMjthcHBpZD15dGFjaHlvbg--/https://s.yimg.com/os/creatr-uploaded-images/2025-03/fa9a73c0-064d-11f0-bfef-335ca4dffab0", "width": 4032, "height": 2688, "tag": "original"}, {"url": "https://s.yimg.com/uu/api/res/1.2/MKqMo4zGxL4RHc2mfKiLcw--~B/Zmk9c3RyaW07aD0xMjg7dz0xNzA7YXBwaWQ9eXRhY2h5b24-/https://s.yimg.com/os/creatr-uploaded-images/2025-03/fa9a73c0-064d-11f0-bfef-335ca4dffab0", "width": 170, "height": 128, "tag": "170x128"}]}, "provider": {"displayName": "Yahoo Finance", "url": "http://finance.yahoo.com/"}, "canonicalUrl": {"url": "https://finance.yahoo.com/news/3-of-goldman-sachs-best-investing-tips-for-currently-volatile-markets-133052214.html", "site": "finance", "region": "US", "lang": "en-US"}, "clickThroughUrl": {"url": "https://finance.yahoo.com/news/3-of-goldman-sachs-best-investing-tips-for-currently-volatile-markets-133052214.html", "site": "finance", "region": "US", "lang": "en-US"}, "metadata": {"editorsPick": true}, "finance": {"premiumFinance": {"isPremiumNews": false, "isPremiumFreeNews": false}}, "storyline": {"storylineItems": [{"content": {"id": "ae5306fc-8f87-4146-8883-7f2f42a80894", "contentType": "STORY", "isHosted": true, "title": "Short sellers have made $15 billion betting against Tesla and Nvidia in 2025", "thumbnail": {"originalUrl": "https://s.yimg.com/os/creatr-uploaded-images/2025-03/d56e9090-059e-11f0-bd69-fb14180a4ab0", "originalWidth": 5221, "originalHeight": 3485, "caption": "", "resolutions": null}, "provider": {"displayName": "Yahoo Finance", "sourceId": "yahoofinance.com"}, "previewUrl": null, "providerContentUrl": "", "canonicalUrl": {"url": "https://finance.yahoo.com/news/short-sellers-have-made-15-billion-betting-against-tesla-and-nvidia-in-2025-164652312.html"}, "clickThroughUrl": {"url": "https://finance.yahoo.com/news/short-sellers-have-made-15-billion-betting-against-tesla-and-nvidia-in-2025-164652312.html"}}}, {"content": {"id": "aa34a3b0-6507-3afc-90e7-5846e662092b", "contentType": "VIDEO", "isHosted": true, "title": "Short sellers have already profited over $24B from Mag 7 losses", "thumbnail": {"originalUrl": "https://s.yimg.com/os/creatr-uploaded-images/2025-03/daf234b0-05d3-11f0-bcf3-ec1e4a3f12eb", "originalWidth": 4606, "originalHeight": 2588, "caption": "", "resolutions": null}, "provider": {"displayName": "Yahoo Finance Video", "sourceId": "video.yahoofinance.com"}, "previewUrl": null, "providerContentUrl": "", "canonicalUrl": {"url": "https://finance.yahoo.com/video/short-sellers-already-profited-over-214233284.html"}, "clickThroughUrl": {"url": "https://finance.yahoo.com/video/short-sellers-already-profited-over-214233284.html"}}}]}}}, {"id": "edd148cd-a04a-38cb-b8e0-edfb5973b784", "content": {"id": "edd148cd-a04a-38cb-b8e0-edfb5973b784", "contentType": "VIDEO", "title": "Uncertainty, lagging Mag 7, rate cut hopes: Market Takeaways", "description": "<p>US equities (<a data-i13n=\"cpos:1;pos:1\" href=\"https://finance.yahoo.com/quote/%5EDJI?p=%5EDJI&.tsrc=fin-srch\">^DJI</a>, <a data-i13n=\"cpos:2;pos:1\" href=\"https://finance.yahoo.com/quote/%5EIXIC?p=%5EIXIC&.tsrc=fin-srch\">^IXIC</a>, <a data-i13n=\"cpos:3;pos:1\" href=\"https://finance.yahoo.com/quote/%5EGSPC?p=%5EGSPC&.tsrc=fin-srch\">^GSPC</a>) slipped lower on Thursday and surrendered thei ...
# Successfully retrieved 5 news articles for GOOGL from Yahoo Finance
# Retrieved 5 news articles for GOOGL

# %%
# Create a function to display news for a specific ticker
def display_news_for_ticker(ticker):
    if ticker in all_news and all_news[ticker]:
        news_df = pd.DataFrame([
            {
                "title": article.title,
                "publication": article.publication,
                "date": article.date,
                "summary": article.summary[:100] + "..." if len(article.summary) > 100 else article.summary
            } for article in all_news[ticker]
        ])
        return news_df
    else:
        return f"No news found for {ticker}"

# %%
# Display news for Microsoft
display_news_for_ticker('MSFT')
# Out:
#                                                title          publication  \
# 0  ChatGPT: Everything you need to know about the...           TechCrunch
# 1  Short sellers have already profited over $24B ...  Yahoo Finance Video
# 2  Accenture reports Q2 beat, Apple TV+ losing $1...             TipRanks
# 3  Microsoft price target raised to $595 from $55...             TipRanks
#
#                  date                                            summary
# 0 2025-03-21 15:46:45  ChatGPT, OpenAI’s text-generating AI chatbot, ...
# 1 2025-03-20 21:42:33  Short sellers, or traders who profit from a st...
# 2 2025-03-21 16:16:26  The major indexes were fractionally higher nea...
# 3 2025-03-21 14:15:09  Tigress Financial analyst Ivan Feinseth raised...
