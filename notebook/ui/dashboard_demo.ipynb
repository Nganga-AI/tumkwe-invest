# %%
import sys
from datetime import datetime
from pathlib import Path

# Add the project root to the Python path
project_root = Path.cwd().parent.parent
if str(project_root) not in sys.path:
	sys.path.append(str(project_root))
project_root
# Out:
# PosixPath('/data/home/eak/learning/nganga_ai/tumkwe-invest/tumkwe-invest')

# %% [markdown]
# # Dashboard Demo
# This notebook demonstrates the usage of the `ui/dashboard.py` module to create a stock analysis dashboard.

# %%
# Import the dashboard module
from tumkwe_invest.ui.dashboard import create_apple_dashboard
import json

# %% [markdown]
# ## Create a Dashboard for Apple Inc.

# %%
# Generate a dashboard configuration for Apple Inc.
dashboard_config = create_apple_dashboard(view_mode="basic")
print(json.dumps(dashboard_config, indent=2))
# Out:
# {
#   "ticker": "AAPL",
#   "company_name": "Apple Inc.",
#   "view_mode": "basic",
#   "sections": {
#     "price": {
#       "title": "Price Information",
#       "components": [
#         {
#           "type": "chart",
#           "config": {
#             "type": "line",
#             "data": {
#               "labels": [
#                 "2025-02-19",
#                 "2025-02-20",
#                 "2025-02-21",
#                 "2025-02-22",
#                 "2025-02-23",
#                 "2025-02-24",
#                 "2025-02-25",
#                 "2025-02-26",
#                 "2025-02-27",
#                 "2025-02-28",
#                 "2025-03-01",
#                 "2025-03-02",
#                 "2025-03-03",
#                 "2025-03-04",
#                 "2025-03-05",
#                 "2025-03-06",
#                 "2025-03-07",
#                 "2025-03-08",
#                 "2025-03-09",
#                 "2025-03-10",
# ...

# %% [markdown]
# ## Switch to Advanced View Mode

# %%
# Generate a dashboard configuration for advanced view mode
dashboard_config_advanced = create_apple_dashboard(view_mode="advanced")
print(json.dumps(dashboard_config_advanced, indent=2))
# Out:
# {
#   "ticker": "AAPL",
#   "company_name": "Apple Inc.",
#   "view_mode": "advanced",
#   "sections": {
#     "price": {
#       "title": "Price Information",
#       "components": [
#         {
#           "type": "chart",
#           "config": {
#             "type": "line",
#             "data": {
#               "labels": [
#                 "2025-02-19",
#                 "2025-02-20",
#                 "2025-02-21",
#                 "2025-02-22",
#                 "2025-02-23",
#                 "2025-02-24",
#                 "2025-02-25",
#                 "2025-02-26",
#                 "2025-02-27",
#                 "2025-02-28",
#                 "2025-03-01",
#                 "2025-03-02",
#                 "2025-03-03",
#                 "2025-03-04",
#                 "2025-03-05",
#                 "2025-03-06",
#                 "2025-03-07",
#                 "2025-03-08",
#                 "2025-03-09",
#                 "2025-03-10",
# ...
